# %%
print("hello world!")

# %%
import os
from dotenv import load_dotenv
from pymongo import MongoClient

# Load environment variables from .env file
load_dotenv()

username = os.getenv('MONGO_USERNAME')
password = os.getenv('MONGO_PASSWORD')
dbname = os.getenv('MONGO_DBNAME')

connection_string = f"mongodb+srv://{username}:{password}@cluster0.mwlsdbh.mongodb.net/{dbname}?retryWrites=true&w=majority"
client = MongoClient(connection_string)

db = client[dbname]
collection = db['matches'] 

result = collection.find_one({"home_team": "England", "away_team": "Scotland"})
print(result)
# Out:
# {'_id': ObjectId('6692ad7288365a953ad9e559'), 'date': datetime.datetime(1873, 3, 8, 0, 0), 'home_team': 'England', 'away_team': 'Scotland', 'home_score': 4, 'away_score': 2, 'tournament': 'Friendly', 'city': 'London', 'country': 'England', 'neutral': False}

# %%
# Find all documents where the age is greater than 25
results = collection.find({"home_score": {"$gt": 4}})

# Print each result
for result in results:
    print(result)
# Out:
# {'_id': ObjectId('6692ad7288365a953ad9e560'), 'date': datetime.datetime(1878, 3, 2, 0, 0), 'home_team': 'Scotland', 'away_team': 'England', 'home_score': 7, 'away_score': 2, 'tournament': 'Friendly', 'city': 'Glasgow', 'country': 'Scotland', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e561'), 'date': datetime.datetime(1878, 3, 23, 0, 0), 'home_team': 'Scotland', 'away_team': 'Wales', 'home_score': 9, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Glasgow', 'country': 'Scotland', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e563'), 'date': datetime.datetime(1879, 4, 5, 0, 0), 'home_team': 'England', 'away_team': 'Scotland', 'home_score': 5, 'away_score': 4, 'tournament': 'Friendly', 'city': 'London', 'country': 'England', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e565'), 'date': datetime.datetime(1880, 3, 13, 0, 0), 'home_team': 'Scotland', 'away_team': 'England', 'home_score': 5, 'away_score': 4, 'tournament': 'Friendly', 'city': 'Glasgow', 'country': 'Scotland', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e567'), 'date': datetime.datetime(1880, 3, 27, 0, 0), 'home_team': 'Scotland', 'away_team': 'Wales', 'home_score': 5, 'away_score': 1, 'tournament': 'Friendly', 'city': 'Glasgow', 'country': 'Scotland', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e56c'), 'date': datetime.datetime(1882, 2, 25, 0, 0), 'home_team': 'Wales', 'away_team': 'Northern Ireland', 'home_score': 7, 'away_score': 1, 'tournament': 'Friendly', 'city': 'Wrexham', 'country': 'Wales', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e56d'), 'date': datetime.datetime(1882, 3, 11, 0, 0), 'home_team': 'Scotland', 'away_team': 'England', 'home_score': 5, 'away_score': 1, 'tournament': 'Friendly', 'city': 'Glasgow', 'country': 'Scotland', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e56e'), 'date': datetime.datetime(1882, 3, 13, 0, 0), 'home_team': 'Wales', 'away_team': 'England', 'home_score': 5, 'away_score': 3, 'tournament': 'Friendly', 'city': 'Wrexham', 'country': 'Wales', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e56f'), 'date': datetime.datetime(1882, 3, 25, 0, 0), 'home_team': 'Scotland', 'away_team': 'Wales', 'home_score': 5, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Glasgow', 'country': 'Scotland', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e570'), 'date': datetime.datetime(1883, 2, 3, 0, 0), 'home_team': 'England', 'away_team': 'Wales', 'home_score': 5, 'away_score': 0, 'tournament': 'Friendly', 'city': 'London', 'country': 'England', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e571'), 'date': datetime.datetime(1883, 2, 24, 0, 0), 'home_team': 'England', 'away_team': 'Northern Ireland', 'home_score': 7, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Liverpool', 'country': 'England', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e576'), 'date': datetime.datetime(1884, 2, 9, 0, 0), 'home_team': 'Wales', 'away_team': 'Northern Ireland', 'home_score': 6, 'away_score': 0, 'tournament': 'British Home Championship', 'city': 'Wrexham', 'country': 'Wales', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e57d'), 'date': datetime.datetime(1885, 3, 14, 0, 0), 'home_team': 'Scotland', 'away_team': 'Northern Ireland', 'home_score': 8, 'away_score': 2, 'tournament': 'British Home Championship', 'city': 'Glasgow', 'country': 'Scotland', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e582'), 'date': datetime.datetime(1886, 2, 27, 0, 0), 'home_team': 'Wales', 'away_team': 'Northern Ireland', 'home_score': 5, 'away_score': 0, 'tournament': 'British Home Championship', 'city': 'Wrexham', 'country': 'Wales', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e589'), 'date': datetime.datetime(1887, 2, 5, 0, 0), 'home_team': 'England', 'away_team': 'Northern Ireland', 'home_score': 7, 'away_score': 0, 'tournament': 'British Home Championship', 'city': 'Sheffield', 'country': 'England', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e58f'), 'date': datetime.datetime(1888, 2, 4, 0, 0), 'home_team': 'England', 'away_team': 'Wales', 'home_score': 5, 'away_score': 1, 'tournament': 'British Home Championship', 'city': 'Crewe', 'country': 'England', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e590'), 'date': datetime.datetime(1888, 3, 3, 0, 0), 'home_team': 'Wales', 'away_team': 'Northern Ireland', 'home_score': 11, 'away_score': 0, 'tournament': 'British Home Championship', 'city': 'Wrexham', 'country': 'Wales', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e591'), 'date': datetime.datetime(1888, 3, 10, 0, 0), 'home_team': 'Scotland', 'away_team': 'Wales', 'home_score': 5, 'away_score': 1, 'tournament': 'British Home Championship', 'city': 'Edinburgh', 'country': 'Scotland', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e597'), 'date': datetime.datetime(1889, 3, 2, 0, 0), 'home_team': 'England', 'away_team': 'Northern Ireland', 'home_score': 6, 'away_score': 1, 'tournament': 'British Home Championship', 'city': 'Liverpool', 'country': 'England', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e598'), 'date': datetime.datetime(1889, 3, 9, 0, 0), 'home_team': 'Scotland', 'away_team': 'Northern Ireland', 'home_score': 7, 'away_score': 0, 'tournament': 'British Home Championship', 'city': 'Glasgow', 'country': 'Scotland', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e59c'), 'date': datetime.datetime(1890, 2, 8, 0, 0), 'home_team': 'Wales', 'away_team': 'Northern Ireland', 'home_score': 5, 'away_score': 2, 'tournament': 'British Home Championship', 'city': 'Shrewsbury', 'country': 'England', 'neutral': True}
# {'_id': ObjectId('6692ad7288365a953ad9e59f'), 'date': datetime.datetime(1890, 3, 22, 0, 0), 'home_team': 'Scotland', 'away_team': 'Wales', 'home_score': 5, 'away_score': 0, 'tournament': 'British Home Championship', 'city': 'Paisley', 'country': 'Scotland', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e5a2'), 'date': datetime.datetime(1891, 2, 7, 0, 0), 'home_team': 'Northern Ireland', 'away_team': 'Wales', 'home_score': 7, 'away_score': 2, 'tournament': 'British Home Championship', 'city': 'Belfast', 'country': 'Ireland', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e5a4'), 'date': datetime.datetime(1891, 3, 7, 0, 0), 'home_team': 'England', 'away_team': 'Northern Ireland', 'home_score': 6, 'away_score': 1, 'tournament': 'British Home Championship', 'city': 'Wolverhampton', 'country': 'England', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e5ac'), 'date': datetime.datetime(1892, 3, 26, 0, 0), 'home_team': 'Scotland', 'away_team': 'Wales', 'home_score': 6, 'away_score': 1, 'tournament': 'British Home Championship', 'city': 'Edinburgh', 'country': 'Scotland', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e5ae'), 'date': datetime.datetime(1893, 2, 25, 0, 0), 'home_team': 'England', 'away_team': 'Northern Ireland', 'home_score': 6, 'away_score': 1, 'tournament': 'British Home Championship', 'city': 'Birmingham', 'country': 'England', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e5af'), 'date': datetime.datetime(1893, 3, 13, 0, 0), 'home_team': 'England', 'away_team': 'Wales', 'home_score': 6, 'away_score': 0, 'tournament': 'British Home Championship', 'city': 'Stoke-on-Trent', 'country': 'England', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e5b1'), 'date': datetime.datetime(1893, 3, 25, 0, 0), 'home_team': 'Scotland', 'away_team': 'Northern Ireland', 'home_score': 6, 'away_score': 1, 'tournament': 'British Home Championship', 'city': 'Glasgow', 'country': 'Scotland', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e5b2'), 'date': datetime.datetime(1893, 4, 1, 0, 0), 'home_team': 'England', 'away_team': 'Scotland', 'home_score': 5, 'away_score': 2, 'tournament': 'British Home Championship', 'city': 'Richmond', 'country': 'England', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e5b6'), 'date': datetime.datetime(1894, 3, 24, 0, 0), 'home_team': 'Scotland', 'away_team': 'Wales', 'home_score': 5, 'away_score': 2, 'tournament': 'British Home Championship', 'city': 'Kilmarnock', 'country': 'Scotland', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e5b9'), 'date': datetime.datetime(1895, 3, 9, 0, 0), 'home_team': 'England', 'away_team': 'Northern Ireland', 'home_score': 9, 'away_score': 0, 'tournament': 'British Home Championship', 'city': 'Derby', 'country': 'England', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e5bf'), 'date': datetime.datetime(1896, 2, 29, 0, 0), 'home_team': 'Wales', 'away_team': 'Northern Ireland', 'home_score': 6, 'away_score': 1, 'tournament': 'British Home Championship', 'city': 'Wrexham', 'country': 'Wales', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e5c5'), 'date': datetime.datetime(1897, 2, 20, 0, 0), 'home_team': 'England', 'away_team': 'Northern Ireland', 'home_score': 6, 'away_score': 0, 'tournament': 'British Home Championship', 'city': 'Nottingham', 'country': 'England', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e5c8'), 'date': datetime.datetime(1897, 3, 27, 0, 0), 'home_team': 'Scotland', 'away_team': 'Northern Ireland', 'home_score': 5, 'away_score': 1, 'tournament': 'British Home Championship', 'city': 'Glasgow', 'country': 'Scotland', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e5cd'), 'date': datetime.datetime(1898, 3, 19, 0, 0), 'home_team': 'Scotland', 'away_team': 'Wales', 'home_score': 5, 'away_score': 2, 'tournament': 'British Home Championship', 'city': 'Motherwell', 'country': 'Scotland', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e5d1'), 'date': datetime.datetime(1899, 2, 18, 0, 0), 'home_team': 'England', 'away_team': 'Northern Ireland', 'home_score': 13, 'away_score': 2, 'tournament': 'British Home Championship', 'city': 'Sunderland', 'country': 'England', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e5d5'), 'date': datetime.datetime(1899, 3, 25, 0, 0), 'home_team': 'Scotland', 'away_team': 'Northern Ireland', 'home_score': 9, 'away_score': 1, 'tournament': 'British Home Championship', 'city': 'Glasgow', 'country': 'Scotland', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e5d7'), 'date': datetime.datetime(1900, 2, 3, 0, 0), 'home_team': 'Scotland', 'away_team': 'Wales', 'home_score': 5, 'away_score': 2, 'tournament': 'British Home Championship', 'city': 'Aberdeen', 'country': 'Scotland', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e5dd'), 'date': datetime.datetime(1901, 2, 23, 0, 0), 'home_team': 'Scotland', 'away_team': 'Northern Ireland', 'home_score': 11, 'away_score': 0, 'tournament': 'British Home Championship', 'city': 'Glasgow', 'country': 'Scotland', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e5e0'), 'date': datetime.datetime(1901, 3, 18, 0, 0), 'home_team': 'England', 'away_team': 'Wales', 'home_score': 6, 'away_score': 0, 'tournament': 'British Home Championship', 'city': 'Newcastle', 'country': 'England', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e5e6'), 'date': datetime.datetime(1902, 3, 15, 0, 0), 'home_team': 'Scotland', 'away_team': 'Wales', 'home_score': 5, 'away_score': 1, 'tournament': 'British Home Championship', 'city': 'Greenock', 'country': 'Scotland', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e5ea'), 'date': datetime.datetime(1902, 10, 12, 0, 0), 'home_team': 'Austria', 'away_team': 'Hungary', 'home_score': 5, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Vienna', 'country': 'Austria', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e5fd'), 'date': datetime.datetime(1904, 10, 9, 0, 0), 'home_team': 'Austria', 'away_team': 'Hungary', 'home_score': 5, 'away_score': 4, 'tournament': 'Friendly', 'city': 'Vienna', 'country': 'Austria', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e606'), 'date': datetime.datetime(1905, 4, 17, 0, 0), 'home_team': 'Guernsey', 'away_team': 'Alderney', 'home_score': 6, 'away_score': 0, 'tournament': 'Muratti Vase', 'city': 'Guernsey', 'country': 'Guernsey', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e609'), 'date': datetime.datetime(1905, 5, 7, 0, 0), 'home_team': 'Belgium', 'away_team': 'France', 'home_score': 7, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Brussels', 'country': 'Belgium', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e616'), 'date': datetime.datetime(1906, 4, 29, 0, 0), 'home_team': 'Belgium', 'away_team': 'Netherlands', 'home_score': 5, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Antwerp', 'country': 'Belgium', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e624'), 'date': datetime.datetime(1907, 4, 7, 0, 0), 'home_team': 'Hungary', 'away_team': 'Czechoslovakia', 'home_score': 5, 'away_score': 2, 'tournament': 'Friendly', 'city': 'Budapest', 'country': 'Hungary', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e629'), 'date': datetime.datetime(1907, 10, 6, 0, 0), 'home_team': 'Czechoslovakia', 'away_team': 'Hungary', 'home_score': 5, 'away_score': 3, 'tournament': 'Friendly', 'city': 'Prague', 'country': 'Bohemia', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e633'), 'date': datetime.datetime(1908, 4, 5, 0, 0), 'home_team': 'Hungary', 'away_team': 'Czechoslovakia', 'home_score': 5, 'away_score': 2, 'tournament': 'Friendly', 'city': 'Budapest', 'country': 'Hungary', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e634'), 'date': datetime.datetime(1908, 4, 5, 0, 0), 'home_team': 'Switzerland', 'away_team': 'Germany', 'home_score': 5, 'away_score': 3, 'tournament': 'Friendly', 'city': 'Basel', 'country': 'Switzerland', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e640'), 'date': datetime.datetime(1908, 7, 12, 0, 0), 'home_team': 'Sweden', 'away_team': 'Norway', 'home_score': 11, 'away_score': 3, 'tournament': 'Friendly', 'city': 'Gothenburg', 'country': 'Sweden', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e644'), 'date': datetime.datetime(1908, 10, 25, 0, 0), 'home_team': 'Netherlands', 'away_team': 'Sweden', 'home_score': 5, 'away_score': 3, 'tournament': 'Friendly', 'city': 'The Hague', 'country': 'Netherlands', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e646'), 'date': datetime.datetime(1908, 11, 1, 0, 0), 'home_team': 'Hungary', 'away_team': 'Austria', 'home_score': 5, 'away_score': 3, 'tournament': 'Friendly', 'city': 'Budapest', 'country': 'Hungary', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e64a'), 'date': datetime.datetime(1909, 3, 15, 0, 0), 'home_team': 'Scotland', 'away_team': 'Northern Ireland', 'home_score': 5, 'away_score': 0, 'tournament': 'British Home Championship', 'city': 'Glasgow', 'country': 'Scotland', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e654'), 'date': datetime.datetime(1909, 5, 9, 0, 0), 'home_team': 'Belgium', 'away_team': 'France', 'home_score': 5, 'away_score': 2, 'tournament': 'Friendly', 'city': 'Brussels', 'country': 'Belgium', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e665'), 'date': datetime.datetime(1910, 4, 7, 0, 0), 'home_team': 'Jersey', 'away_team': 'Alderney', 'home_score': 7, 'away_score': 1, 'tournament': 'Muratti Vase', 'city': 'Jersey', 'country': 'Jersey', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e666'), 'date': datetime.datetime(1910, 4, 10, 0, 0), 'home_team': 'Netherlands', 'away_team': 'Belgium', 'home_score': 7, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Haarlem', 'country': 'Netherlands', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e66b'), 'date': datetime.datetime(1910, 5, 15, 0, 0), 'home_team': 'Italy', 'away_team': 'France', 'home_score': 6, 'away_score': 2, 'tournament': 'Friendly', 'city': 'Milan', 'country': 'Italy', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e66d'), 'date': datetime.datetime(1910, 5, 26, 0, 0), 'home_team': 'Hungary', 'away_team': 'Italy', 'home_score': 6, 'away_score': 1, 'tournament': 'Friendly', 'city': 'Budapest', 'country': 'Hungary', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e670'), 'date': datetime.datetime(1910, 6, 5, 0, 0), 'home_team': 'Argentina', 'away_team': 'Chile', 'home_score': 5, 'away_score': 1, 'tournament': 'Friendly', 'city': 'Buenos Aires', 'country': 'Argentina', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e682'), 'date': datetime.datetime(1911, 3, 26, 0, 0), 'home_team': 'Germany', 'away_team': 'Switzerland', 'home_score': 6, 'away_score': 2, 'tournament': 'Friendly', 'city': 'Stuttgart', 'country': 'Germany', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e688'), 'date': datetime.datetime(1911, 4, 23, 0, 0), 'home_team': 'Switzerland', 'away_team': 'France', 'home_score': 5, 'away_score': 2, 'tournament': 'Friendly', 'city': 'Geneva', 'country': 'Switzerland', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e68a'), 'date': datetime.datetime(1911, 4, 30, 0, 0), 'home_team': 'Belgium', 'away_team': 'France', 'home_score': 7, 'away_score': 1, 'tournament': 'Friendly', 'city': 'Uccle', 'country': 'Belgium', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e697'), 'date': datetime.datetime(1911, 10, 29, 0, 0), 'home_team': 'Hungary', 'away_team': 'Switzerland', 'home_score': 9, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Budapest', 'country': 'Hungary', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e69e'), 'date': datetime.datetime(1912, 2, 10, 0, 0), 'home_team': 'France', 'away_team': 'Catalonia', 'home_score': 7, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Paris', 'country': 'France', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e6a0'), 'date': datetime.datetime(1912, 2, 20, 0, 0), 'home_team': 'Belgium', 'away_team': 'Switzerland', 'home_score': 9, 'away_score': 2, 'tournament': 'Friendly', 'city': 'Antwerp', 'country': 'Belgium', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e6a7'), 'date': datetime.datetime(1912, 3, 24, 0, 0), 'home_team': 'Netherlands', 'away_team': 'Germany', 'home_score': 5, 'away_score': 5, 'tournament': 'Friendly', 'city': 'Zwolle', 'country': 'Netherlands', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e6b3'), 'date': datetime.datetime(1912, 6, 27, 0, 0), 'home_team': 'Sweden', 'away_team': 'Finland', 'home_score': 7, 'away_score': 1, 'tournament': 'Friendly', 'city': 'Solna', 'country': 'Sweden', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e6b4'), 'date': datetime.datetime(1912, 6, 30, 0, 0), 'home_team': 'Austria', 'away_team': 'Italy', 'home_score': 5, 'away_score': 1, 'tournament': 'Friendly', 'city': 'Stockholm', 'country': 'Sweden', 'neutral': True}
# {'_id': ObjectId('6692ad7288365a953ad9e6d0'), 'date': datetime.datetime(1913, 4, 3, 0, 0), 'home_team': 'Jersey', 'away_team': 'Alderney', 'home_score': 5, 'away_score': 2, 'tournament': 'Muratti Vase', 'city': 'Guernsey', 'country': 'Guernsey', 'neutral': True}
# {'_id': ObjectId('6692ad7288365a953ad9e6d3'), 'date': datetime.datetime(1913, 4, 20, 0, 0), 'home_team': 'France', 'away_team': 'Luxembourg', 'home_score': 8, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Saint-Ouen', 'country': 'France', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e6db'), 'date': datetime.datetime(1913, 5, 25, 0, 0), 'home_team': 'Denmark', 'away_team': 'Sweden', 'home_score': 8, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Copenhagen', 'country': 'Denmark', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e6dc'), 'date': datetime.datetime(1913, 6, 8, 0, 0), 'home_team': 'Sweden', 'away_team': 'Norway', 'home_score': 9, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Stockholm', 'country': 'Sweden', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e6eb'), 'date': datetime.datetime(1913, 11, 23, 0, 0), 'home_team': 'Belgium', 'away_team': 'Germany', 'home_score': 6, 'away_score': 2, 'tournament': 'Friendly', 'city': 'Antwerp', 'country': 'Belgium', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e6ef'), 'date': datetime.datetime(1914, 2, 8, 0, 0), 'home_team': 'Luxembourg', 'away_team': 'France', 'home_score': 5, 'away_score': 4, 'tournament': 'Friendly', 'city': 'Luxembourg', 'country': 'Luxembourg', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e701'), 'date': datetime.datetime(1914, 5, 31, 0, 0), 'home_team': 'Hungary', 'away_team': 'France', 'home_score': 5, 'away_score': 1, 'tournament': 'Friendly', 'city': 'Budapest', 'country': 'Hungary', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e70b'), 'date': datetime.datetime(1914, 10, 25, 0, 0), 'home_team': 'Sweden', 'away_team': 'Norway', 'home_score': 7, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Solna', 'country': 'Sweden', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e70d'), 'date': datetime.datetime(1915, 1, 3, 0, 0), 'home_team': 'Basque Country', 'away_team': 'Catalonia', 'home_score': 6, 'away_score': 1, 'tournament': 'Friendly', 'city': 'Bilbao', 'country': 'Spain', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e71a'), 'date': datetime.datetime(1915, 9, 19, 0, 0), 'home_team': 'Denmark', 'away_team': 'Norway', 'home_score': 8, 'away_score': 1, 'tournament': 'Friendly', 'city': 'Copenhagen', 'country': 'Denmark', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e71c'), 'date': datetime.datetime(1915, 10, 24, 0, 0), 'home_team': 'Sweden', 'away_team': 'Norway', 'home_score': 5, 'away_score': 2, 'tournament': 'Friendly', 'city': 'Stockholm', 'country': 'Sweden', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e71e'), 'date': datetime.datetime(1915, 11, 7, 0, 0), 'home_team': 'Hungary', 'away_team': 'Austria', 'home_score': 6, 'away_score': 2, 'tournament': 'Friendly', 'city': 'Budapest', 'country': 'Hungary', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e724'), 'date': datetime.datetime(1916, 6, 4, 0, 0), 'home_team': 'Basque Country', 'away_team': 'Catalonia', 'home_score': 5, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Bilbao', 'country': 'Spain', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e727'), 'date': datetime.datetime(1916, 7, 2, 0, 0), 'home_team': 'Sweden', 'away_team': 'Norway', 'home_score': 6, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Stockholm', 'country': 'Sweden', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e728'), 'date': datetime.datetime(1916, 7, 6, 0, 0), 'home_team': 'Argentina', 'away_team': 'Chile', 'home_score': 6, 'away_score': 1, 'tournament': 'Copa América', 'city': 'Buenos Aires', 'country': 'Argentina', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e734'), 'date': datetime.datetime(1916, 10, 1, 0, 0), 'home_team': 'Argentina', 'away_team': 'Uruguay', 'home_score': 7, 'away_score': 2, 'tournament': 'Friendly', 'city': 'Avellaneda', 'country': 'Argentina', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e739'), 'date': datetime.datetime(1916, 10, 15, 0, 0), 'home_team': 'Denmark', 'away_team': 'Norway', 'home_score': 8, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Copenhagen', 'country': 'Denmark', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e742'), 'date': datetime.datetime(1917, 6, 3, 0, 0), 'home_team': 'Hungary', 'away_team': 'Austria', 'home_score': 6, 'away_score': 2, 'tournament': 'Friendly', 'city': 'Budapest', 'country': 'Hungary', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e74d'), 'date': datetime.datetime(1917, 10, 7, 0, 0), 'home_team': 'Denmark', 'away_team': 'Norway', 'home_score': 12, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Copenhagen', 'country': 'Denmark', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e750'), 'date': datetime.datetime(1917, 10, 12, 0, 0), 'home_team': 'Brazil', 'away_team': 'Chile', 'home_score': 5, 'away_score': 0, 'tournament': 'Copa América', 'city': 'Montevideo', 'country': 'Uruguay', 'neutral': True}
# {'_id': ObjectId('6692ad7288365a953ad9e758'), 'date': datetime.datetime(1918, 5, 9, 0, 0), 'home_team': 'Austria', 'away_team': 'Switzerland', 'home_score': 5, 'away_score': 1, 'tournament': 'Friendly', 'city': 'Vienna', 'country': 'Austria', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e76b'), 'date': datetime.datetime(1919, 5, 11, 0, 0), 'home_team': 'Brazil', 'away_team': 'Chile', 'home_score': 6, 'away_score': 0, 'tournament': 'Copa América', 'city': 'Rio de Janeiro', 'country': 'Brazil', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e77d'), 'date': datetime.datetime(1919, 6, 12, 0, 0), 'home_team': 'Denmark', 'away_team': 'Norway', 'home_score': 5, 'away_score': 1, 'tournament': 'Friendly', 'city': 'Copenhagen', 'country': 'Denmark', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e789'), 'date': datetime.datetime(1919, 10, 19, 0, 0), 'home_team': 'Argentina', 'away_team': 'Uruguay', 'home_score': 6, 'away_score': 1, 'tournament': 'Copa Premio Honor Argentino', 'city': 'Buenos Aires', 'country': 'Argentina', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e78d'), 'date': datetime.datetime(1920, 1, 18, 0, 0), 'home_team': 'Italy', 'away_team': 'France', 'home_score': 9, 'away_score': 4, 'tournament': 'Friendly', 'city': 'Milan', 'country': 'Italy', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e796'), 'date': datetime.datetime(1920, 4, 10, 0, 0), 'home_team': 'England', 'away_team': 'Scotland', 'home_score': 5, 'away_score': 4, 'tournament': 'British Home Championship', 'city': 'Sheffield', 'country': 'England', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e7ae'), 'date': datetime.datetime(1920, 10, 17, 0, 0), 'home_team': 'Finland', 'away_team': 'Estonia', 'home_score': 6, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Helsinki', 'country': 'Finland', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e7d8'), 'date': datetime.datetime(1921, 9, 14, 0, 0), 'home_team': 'Costa Rica', 'away_team': 'El Salvador', 'home_score': 7, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Guatemala City', 'country': 'Guatemala', 'neutral': True}
# {'_id': ObjectId('6692ad7288365a953ad9e7e4'), 'date': datetime.datetime(1921, 10, 28, 0, 0), 'home_team': 'Czechoslovakia', 'away_team': 'Yugoslavia', 'home_score': 6, 'away_score': 1, 'tournament': 'Friendly', 'city': 'Prague', 'country': 'Czechoslovakia', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e7f6'), 'date': datetime.datetime(1922, 4, 6, 0, 0), 'home_team': 'Guernsey', 'away_team': 'Alderney', 'home_score': 8, 'away_score': 0, 'tournament': 'Muratti Vase', 'city': 'Guernsey', 'country': 'Guernsey', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e806'), 'date': datetime.datetime(1922, 6, 11, 0, 0), 'home_team': 'Austria', 'away_team': 'Switzerland', 'home_score': 7, 'away_score': 1, 'tournament': 'Friendly', 'city': 'Vienna', 'country': 'Austria', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e808'), 'date': datetime.datetime(1922, 6, 11, 0, 0), 'home_team': 'Norway', 'away_team': 'France', 'home_score': 7, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Kristiania', 'country': 'Norway', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e811'), 'date': datetime.datetime(1922, 8, 11, 0, 0), 'home_team': 'Finland', 'away_team': 'Estonia', 'home_score': 10, 'away_score': 2, 'tournament': 'Friendly', 'city': 'Helsinki', 'country': 'Finland', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e82c'), 'date': datetime.datetime(1922, 11, 19, 0, 0), 'home_team': 'Switzerland', 'away_team': 'Netherlands', 'home_score': 5, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Berne', 'country': 'Switzerland', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e843'), 'date': datetime.datetime(1923, 3, 19, 0, 0), 'home_team': 'England', 'away_team': 'Belgium', 'home_score': 6, 'away_score': 1, 'tournament': 'Friendly', 'city': 'London', 'country': 'England', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e844'), 'date': datetime.datetime(1923, 4, 2, 0, 0), 'home_team': 'Netherlands', 'away_team': 'France', 'home_score': 8, 'away_score': 1, 'tournament': 'Friendly', 'city': 'Amsterdam', 'country': 'Netherlands', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e85a'), 'date': datetime.datetime(1923, 5, 27, 0, 0), 'home_team': 'Czechoslovakia', 'away_team': 'Italy', 'home_score': 5, 'away_score': 1, 'tournament': 'Friendly', 'city': 'Prague', 'country': 'Czechoslovakia', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e863'), 'date': datetime.datetime(1923, 6, 20, 0, 0), 'home_team': 'Sweden', 'away_team': 'Finland', 'home_score': 5, 'away_score': 4, 'tournament': 'Friendly', 'city': 'Gävle', 'country': 'Sweden', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e873'), 'date': datetime.datetime(1923, 9, 23, 0, 0), 'home_team': 'Finland', 'away_team': 'Poland', 'home_score': 5, 'away_score': 3, 'tournament': 'Friendly', 'city': 'Helsinki', 'country': 'Finland', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e8a0'), 'date': datetime.datetime(1924, 4, 6, 0, 0), 'home_team': 'Hungary', 'away_team': 'Italy', 'home_score': 7, 'away_score': 1, 'tournament': 'Friendly', 'city': 'Budapest', 'country': 'Hungary', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e8ac'), 'date': datetime.datetime(1924, 5, 18, 0, 0), 'home_team': 'Sweden', 'away_team': 'Poland', 'home_score': 5, 'away_score': 1, 'tournament': 'Friendly', 'city': 'Stockholm', 'country': 'Sweden', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e8af'), 'date': datetime.datetime(1924, 5, 21, 0, 0), 'home_team': 'Austria', 'away_team': 'Bulgaria', 'home_score': 6, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Vienna', 'country': 'Austria', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e8b3'), 'date': datetime.datetime(1924, 5, 25, 0, 0), 'home_team': 'Czechoslovakia', 'away_team': 'Turkey', 'home_score': 5, 'away_score': 2, 'tournament': 'Olympic Games', 'city': 'Paris', 'country': 'France', 'neutral': True}
# {'_id': ObjectId('6692ad7288365a953ad9e8b4'), 'date': datetime.datetime(1924, 5, 25, 0, 0), 'home_team': 'Switzerland', 'away_team': 'Lithuania', 'home_score': 9, 'away_score': 0, 'tournament': 'Olympic Games', 'city': 'Vincennes', 'country': 'France', 'neutral': True}
# {'_id': ObjectId('6692ad7288365a953ad9e8b6'), 'date': datetime.datetime(1924, 5, 26, 0, 0), 'home_team': 'Uruguay', 'away_team': 'Yugoslavia', 'home_score': 7, 'away_score': 0, 'tournament': 'Olympic Games', 'city': 'Colombes', 'country': 'France', 'neutral': True}
# {'_id': ObjectId('6692ad7288365a953ad9e8b7'), 'date': datetime.datetime(1924, 5, 26, 0, 0), 'home_team': 'Hungary', 'away_team': 'Poland', 'home_score': 5, 'away_score': 0, 'tournament': 'Olympic Games', 'city': 'Paris', 'country': 'France', 'neutral': True}
# {'_id': ObjectId('6692ad7288365a953ad9e8b8'), 'date': datetime.datetime(1924, 5, 27, 0, 0), 'home_team': 'Egypt', 'away_team': 'Lithuania', 'home_score': 10, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Vincennes', 'country': 'France', 'neutral': True}
# {'_id': ObjectId('6692ad7288365a953ad9e8b9'), 'date': datetime.datetime(1924, 5, 27, 0, 0), 'home_team': 'France', 'away_team': 'Latvia', 'home_score': 7, 'away_score': 0, 'tournament': 'Olympic Games', 'city': 'Paris', 'country': 'France', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e8ba'), 'date': datetime.datetime(1924, 5, 27, 0, 0), 'home_team': 'Netherlands', 'away_team': 'Romania', 'home_score': 6, 'away_score': 0, 'tournament': 'Olympic Games', 'city': 'Colombes', 'country': 'France', 'neutral': True}
# {'_id': ObjectId('6692ad7288365a953ad9e8be'), 'date': datetime.datetime(1924, 5, 29, 0, 0), 'home_team': 'Sweden', 'away_team': 'Belgium', 'home_score': 8, 'away_score': 1, 'tournament': 'Olympic Games', 'city': 'Colombes', 'country': 'France', 'neutral': True}
# {'_id': ObjectId('6692ad7288365a953ad9e8c3'), 'date': datetime.datetime(1924, 6, 1, 0, 0), 'home_team': 'Sweden', 'away_team': 'Egypt', 'home_score': 5, 'away_score': 0, 'tournament': 'Olympic Games', 'city': 'Paris', 'country': 'France', 'neutral': True}
# {'_id': ObjectId('6692ad7288365a953ad9e8d9'), 'date': datetime.datetime(1924, 6, 29, 0, 0), 'home_team': 'Sweden', 'away_team': 'Egypt', 'home_score': 5, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Stockholm', 'country': 'Sweden', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e8db'), 'date': datetime.datetime(1924, 7, 25, 0, 0), 'home_team': 'Sweden', 'away_team': 'Estonia', 'home_score': 5, 'away_score': 2, 'tournament': 'Friendly', 'city': 'Stockholm', 'country': 'Sweden', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e8dd'), 'date': datetime.datetime(1924, 7, 28, 0, 0), 'home_team': 'Finland', 'away_team': 'Sweden', 'home_score': 5, 'away_score': 7, 'tournament': 'Friendly', 'city': 'Helsinki', 'country': 'Finland', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e8e9'), 'date': datetime.datetime(1924, 9, 21, 0, 0), 'home_team': 'Sweden', 'away_team': 'Norway', 'home_score': 6, 'away_score': 1, 'tournament': 'Nordic Championship', 'city': 'Solna', 'country': 'Sweden', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e8f1'), 'date': datetime.datetime(1924, 10, 19, 0, 0), 'home_team': 'Uruguay', 'away_team': 'Chile', 'home_score': 5, 'away_score': 0, 'tournament': 'Copa América', 'city': 'Montevideo', 'country': 'Uruguay', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e908'), 'date': datetime.datetime(1925, 3, 22, 0, 0), 'home_team': 'Italy', 'away_team': 'France', 'home_score': 7, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Turin', 'country': 'Italy', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e909'), 'date': datetime.datetime(1925, 3, 25, 0, 0), 'home_team': 'Hungary', 'away_team': 'Switzerland', 'home_score': 5, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Budapest', 'country': 'Hungary', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e915'), 'date': datetime.datetime(1925, 5, 3, 0, 0), 'home_team': 'Netherlands', 'away_team': 'Belgium', 'home_score': 5, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Amsterdam', 'country': 'Netherlands', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e928'), 'date': datetime.datetime(1925, 6, 21, 0, 0), 'home_team': 'Denmark', 'away_team': 'Norway', 'home_score': 5, 'away_score': 1, 'tournament': 'Nordic Championship', 'city': 'Copenhagen', 'country': 'Denmark', 'neutral': False}
# {'_id': ObjectId('6692ad7288365a953ad9e932'), 'date': datetime.datetime(1925, 7, 12, 0, 0), 'home_team': 'Sweden', 'away_team': 'Hungary', 'home_score': 6, 'away_score': 2, 'tournament': 'Friendly', 'city': 'Stockholm', 'country': 'Sweden', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9e948'), 'date': datetime.datetime(1925, 10, 28, 0, 0), 'home_team': 'Czechoslovakia', 'away_team': 'Yugoslavia', 'home_score': 7, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Prague', 'country': 'Czechoslovakia', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9e94e'), 'date': datetime.datetime(1925, 11, 8, 0, 0), 'home_team': 'United States', 'away_team': 'Canada', 'home_score': 6, 'away_score': 1, 'tournament': 'Friendly', 'city': 'New York', 'country': 'United States', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9e950'), 'date': datetime.datetime(1925, 12, 6, 0, 0), 'home_team': 'Brazil', 'away_team': 'Paraguay', 'home_score': 5, 'away_score': 2, 'tournament': 'Copa América', 'city': 'Buenos Aires', 'country': 'Argentina', 'neutral': True}
# {'_id': ObjectId('6692ad7388365a953ad9e965'), 'date': datetime.datetime(1926, 3, 28, 0, 0), 'home_team': 'Netherlands', 'away_team': 'Switzerland', 'home_score': 5, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Amsterdam', 'country': 'Netherlands', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9e96d'), 'date': datetime.datetime(1926, 4, 25, 0, 0), 'home_team': 'Romania', 'away_team': 'Bulgaria', 'home_score': 6, 'away_score': 1, 'tournament': 'Friendly', 'city': 'Bucharest', 'country': 'Romania', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9e96e'), 'date': datetime.datetime(1926, 4, 29, 0, 0), 'home_team': 'Jersey', 'away_team': 'Alderney', 'home_score': 7, 'away_score': 1, 'tournament': 'Muratti Vase', 'city': 'Jersey', 'country': 'Jersey', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9e988'), 'date': datetime.datetime(1926, 7, 18, 0, 0), 'home_team': 'Sweden', 'away_team': 'Italy', 'home_score': 5, 'away_score': 3, 'tournament': 'Friendly', 'city': 'Stockholm', 'country': 'Sweden', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9e98c'), 'date': datetime.datetime(1926, 8, 8, 0, 0), 'home_team': 'Poland', 'away_team': 'Finland', 'home_score': 7, 'away_score': 1, 'tournament': 'Friendly', 'city': 'Poznań', 'country': 'Poland', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9e991'), 'date': datetime.datetime(1926, 9, 12, 0, 0), 'home_team': 'Poland', 'away_team': 'Turkey', 'home_score': 6, 'away_score': 1, 'tournament': 'Friendly', 'city': 'Lwów', 'country': 'Poland', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9e999'), 'date': datetime.datetime(1926, 10, 10, 0, 0), 'home_team': 'Austria', 'away_team': 'Switzerland', 'home_score': 7, 'away_score': 1, 'tournament': 'Friendly', 'city': 'Vienna', 'country': 'Austria', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9e99a'), 'date': datetime.datetime(1926, 10, 12, 0, 0), 'home_team': 'Chile', 'away_team': 'Bolivia', 'home_score': 7, 'away_score': 1, 'tournament': 'Copa América', 'city': 'Santiago', 'country': 'Chile', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9e99b'), 'date': datetime.datetime(1926, 10, 16, 0, 0), 'home_team': 'Argentina', 'away_team': 'Bolivia', 'home_score': 5, 'away_score': 0, 'tournament': 'Copa América', 'city': 'Santiago', 'country': 'Chile', 'neutral': True}
# {'_id': ObjectId('6692ad7388365a953ad9e99d'), 'date': datetime.datetime(1926, 10, 20, 0, 0), 'home_team': 'Argentina', 'away_team': 'Paraguay', 'home_score': 8, 'away_score': 0, 'tournament': 'Copa América', 'city': 'Santiago', 'country': 'Chile', 'neutral': True}
# {'_id': ObjectId('6692ad7388365a953ad9e9a7'), 'date': datetime.datetime(1926, 11, 3, 0, 0), 'home_team': 'Chile', 'away_team': 'Paraguay', 'home_score': 5, 'away_score': 1, 'tournament': 'Copa América', 'city': 'Santiago', 'country': 'Chile', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9e9a8'), 'date': datetime.datetime(1926, 11, 6, 0, 0), 'home_team': 'United States', 'away_team': 'Canada', 'home_score': 6, 'away_score': 2, 'tournament': 'Friendly', 'city': 'New York', 'country': 'United States', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9e9ab'), 'date': datetime.datetime(1926, 11, 20, 0, 0), 'home_team': 'Jamaica', 'away_team': 'Haiti', 'home_score': 6, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Kingston', 'country': 'Jamaica', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9e9bb'), 'date': datetime.datetime(1927, 4, 10, 0, 0), 'home_team': 'Austria', 'away_team': 'Hungary', 'home_score': 6, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Vienna', 'country': 'Austria', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9e9cd'), 'date': datetime.datetime(1927, 5, 29, 0, 0), 'home_team': 'Sweden', 'away_team': 'Latvia', 'home_score': 12, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Stockholm', 'country': 'Sweden', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9e9d0'), 'date': datetime.datetime(1927, 6, 12, 0, 0), 'home_team': 'Hungary', 'away_team': 'France', 'home_score': 13, 'away_score': 1, 'tournament': 'Friendly', 'city': 'Budapest', 'country': 'Hungary', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9e9d1'), 'date': datetime.datetime(1927, 6, 12, 0, 0), 'home_team': 'Sweden', 'away_team': 'Finland', 'home_score': 6, 'away_score': 2, 'tournament': 'Friendly', 'city': 'Stockholm', 'country': 'Sweden', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9e9de'), 'date': datetime.datetime(1927, 7, 27, 0, 0), 'home_team': 'Latvia', 'away_team': 'Lithuania', 'home_score': 6, 'away_score': 3, 'tournament': 'Friendly', 'city': 'Riga', 'country': 'Latvia', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9e9e1'), 'date': datetime.datetime(1927, 8, 27, 0, 0), 'home_team': 'China PR', 'away_team': 'Japan', 'home_score': 5, 'away_score': 1, 'tournament': 'Friendly', 'city': 'Shanghai', 'country': 'China PR', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9e9e2'), 'date': datetime.datetime(1927, 8, 27, 0, 0), 'home_team': 'China PR', 'away_team': 'Japan', 'home_score': 5, 'away_score': 1, 'tournament': 'Far Eastern Championship Games', 'city': 'Shanghai', 'country': 'China PR', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9e9e8'), 'date': datetime.datetime(1927, 9, 4, 0, 0), 'home_team': 'Sweden', 'away_team': 'Belgium', 'home_score': 7, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Stockholm', 'country': 'Sweden', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9e9eb'), 'date': datetime.datetime(1927, 9, 25, 0, 0), 'home_team': 'Hungary', 'away_team': 'Austria', 'home_score': 5, 'away_score': 3, 'tournament': 'Central European International Cup', 'city': 'Budapest', 'country': 'Hungary', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9e9f2'), 'date': datetime.datetime(1927, 10, 23, 0, 0), 'home_team': 'Germany', 'away_team': 'Norway', 'home_score': 6, 'away_score': 2, 'tournament': 'Friendly', 'city': 'Altona', 'country': 'Germany', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9e9f3'), 'date': datetime.datetime(1927, 10, 28, 0, 0), 'home_team': 'Czechoslovakia', 'away_team': 'Yugoslavia', 'home_score': 5, 'away_score': 3, 'tournament': 'Friendly', 'city': 'Prague', 'country': 'Czechoslovakia', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9e9f5'), 'date': datetime.datetime(1927, 10, 30, 0, 0), 'home_team': 'Argentina', 'away_team': 'Bolivia', 'home_score': 7, 'away_score': 1, 'tournament': 'Copa América', 'city': 'Lima', 'country': 'Peru', 'neutral': True}
# {'_id': ObjectId('6692ad7388365a953ad9ea20'), 'date': datetime.datetime(1928, 5, 6, 0, 0), 'home_team': 'Hungary', 'away_team': 'Austria', 'home_score': 5, 'away_score': 5, 'tournament': 'Friendly', 'city': 'Budapest', 'country': 'Hungary', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9ea27'), 'date': datetime.datetime(1928, 5, 27, 0, 0), 'home_team': 'Belgium', 'away_team': 'Luxembourg', 'home_score': 5, 'away_score': 3, 'tournament': 'Olympic Games', 'city': 'Amsterdam', 'country': 'Netherlands', 'neutral': True}
# {'_id': ObjectId('6692ad7388365a953ad9ea29'), 'date': datetime.datetime(1928, 5, 28, 0, 0), 'home_team': 'Egypt', 'away_team': 'Turkey', 'home_score': 7, 'away_score': 1, 'tournament': 'Olympic Games', 'city': 'Amsterdam', 'country': 'Netherlands', 'neutral': True}
# {'_id': ObjectId('6692ad7388365a953ad9ea2c'), 'date': datetime.datetime(1928, 5, 29, 0, 0), 'home_team': 'Argentina', 'away_team': 'United States', 'home_score': 11, 'away_score': 2, 'tournament': 'Olympic Games', 'city': 'Amsterdam', 'country': 'Netherlands', 'neutral': True}
# {'_id': ObjectId('6692ad7388365a953ad9ea2d'), 'date': datetime.datetime(1928, 5, 30, 0, 0), 'home_team': 'Spain', 'away_team': 'Mexico', 'home_score': 7, 'away_score': 1, 'tournament': 'Olympic Games', 'city': 'Amsterdam', 'country': 'Netherlands', 'neutral': True}
# {'_id': ObjectId('6692ad7388365a953ad9ea30'), 'date': datetime.datetime(1928, 6, 2, 0, 0), 'home_team': 'Argentina', 'away_team': 'Belgium', 'home_score': 6, 'away_score': 3, 'tournament': 'Olympic Games', 'city': 'Amsterdam', 'country': 'Netherlands', 'neutral': True}
# {'_id': ObjectId('6692ad7388365a953ad9ea33'), 'date': datetime.datetime(1928, 6, 4, 0, 0), 'home_team': 'Italy', 'away_team': 'Spain', 'home_score': 7, 'away_score': 1, 'tournament': 'Olympic Games', 'city': 'Amsterdam', 'country': 'Netherlands', 'neutral': True}
# {'_id': ObjectId('6692ad7388365a953ad9ea37'), 'date': datetime.datetime(1928, 6, 6, 0, 0), 'home_team': 'Argentina', 'away_team': 'Egypt', 'home_score': 6, 'away_score': 0, 'tournament': 'Olympic Games', 'city': 'Amsterdam', 'country': 'Netherlands', 'neutral': True}
# {'_id': ObjectId('6692ad7388365a953ad9ea38'), 'date': datetime.datetime(1928, 6, 7, 0, 0), 'home_team': 'Sweden', 'away_team': 'Norway', 'home_score': 6, 'away_score': 1, 'tournament': 'Nordic Championship', 'city': 'Stockholm', 'country': 'Sweden', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9ea3b'), 'date': datetime.datetime(1928, 6, 9, 0, 0), 'home_team': 'Italy', 'away_team': 'Egypt', 'home_score': 11, 'away_score': 3, 'tournament': 'Olympic Games', 'city': 'Amsterdam', 'country': 'Netherlands', 'neutral': True}
# {'_id': ObjectId('6692ad7388365a953ad9ea46'), 'date': datetime.datetime(1928, 7, 26, 0, 0), 'home_team': 'Estonia', 'away_team': 'Lithuania', 'home_score': 6, 'away_score': 0, 'tournament': 'Baltic Cup', 'city': 'Tallinn', 'country': 'Estonia', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9ea4b'), 'date': datetime.datetime(1928, 8, 17, 0, 0), 'home_team': 'Belarus', 'away_team': 'Switzerland', 'home_score': 6, 'away_score': 3, 'tournament': 'Friendly', 'city': 'Moscow', 'country': 'Soviet Union', 'neutral': True}
# {'_id': ObjectId('6692ad7388365a953ad9ea55'), 'date': datetime.datetime(1928, 9, 23, 0, 0), 'home_team': 'Czechoslovakia', 'away_team': 'Hungary', 'home_score': 6, 'away_score': 1, 'tournament': 'Friendly', 'city': 'Prague', 'country': 'Czechoslovakia', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9ea59'), 'date': datetime.datetime(1928, 10, 7, 0, 0), 'home_team': 'Austria', 'away_team': 'Hungary', 'home_score': 5, 'away_score': 1, 'tournament': 'Central European International Cup', 'city': 'Vienna', 'country': 'Austria', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9ea60'), 'date': datetime.datetime(1928, 10, 28, 0, 0), 'home_team': 'Czechoslovakia', 'away_team': 'Yugoslavia', 'home_score': 7, 'away_score': 1, 'tournament': 'Friendly', 'city': 'Prague', 'country': 'Czechoslovakia', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9ea66'), 'date': datetime.datetime(1928, 12, 7, 0, 0), 'home_team': 'El Salvador', 'away_team': 'Honduras', 'home_score': 5, 'away_score': 0, 'tournament': 'Friendly', 'city': 'San Salvador', 'country': 'El Salvador', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9ea68'), 'date': datetime.datetime(1929, 2, 10, 0, 0), 'home_team': 'Germany', 'away_team': 'Switzerland', 'home_score': 7, 'away_score': 1, 'tournament': 'Friendly', 'city': 'Mannheim', 'country': 'Germany', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9ea6e'), 'date': datetime.datetime(1929, 3, 17, 0, 0), 'home_team': 'Spain', 'away_team': 'Portugal', 'home_score': 5, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Seville', 'country': 'Spain', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9ea72'), 'date': datetime.datetime(1929, 4, 14, 0, 0), 'home_team': 'Spain', 'away_team': 'France', 'home_score': 8, 'away_score': 1, 'tournament': 'Friendly', 'city': 'Zaragoza', 'country': 'Spain', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9ea7b'), 'date': datetime.datetime(1929, 5, 1, 0, 0), 'home_team': 'El Salvador', 'away_team': 'Nicaragua', 'home_score': 9, 'away_score': 0, 'tournament': 'Friendly', 'city': 'San Salvador', 'country': 'El Salvador', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9ea7c'), 'date': datetime.datetime(1929, 5, 2, 0, 0), 'home_team': 'Guernsey', 'away_team': 'Alderney', 'home_score': 5, 'away_score': 0, 'tournament': 'Muratti Vase', 'city': 'Guernsey', 'country': 'Guernsey', 'neutral': False}
# {'_id': ObjectId('6692ad7388365a953ad9ea8a'), 'date': datetime.datetime(1929, 6, 9, 0, 0), 'home_team': 'Sweden', 'away_team': 'Netherlands', 'home_score': 6, 'away_score': 2, 'tournament': 'Friendly', 'city': 'Stockholm', 'country': 'Sweden', 'neutral': False}
# ...
# {'_id': ObjectId('6692ad8188365a953ada9aa3'), 'date': datetime.datetime(2023, 10, 12, 0, 0), 'home_team': 'Myanmar', 'away_team': 'Macau', 'home_score': 5, 'away_score': 1, 'tournament': 'FIFA World Cup qualification', 'city': 'Yangon', 'country': 'Myanmar', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9aa7'), 'date': datetime.datetime(2023, 10, 12, 0, 0), 'home_team': 'Algeria', 'away_team': 'Cape Verde', 'home_score': 5, 'away_score': 1, 'tournament': 'Friendly', 'city': 'Constantine', 'country': 'Algeria', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9aaa'), 'date': datetime.datetime(2023, 10, 12, 0, 0), 'home_team': 'Georgia', 'away_team': 'Thailand', 'home_score': 8, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Tbilisi', 'country': 'Georgia', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9af2'), 'date': datetime.datetime(2023, 10, 16, 0, 0), 'home_team': 'Dominican Republic', 'away_team': 'Barbados', 'home_score': 5, 'away_score': 2, 'tournament': 'CONCACAF Nations League', 'city': 'Santiago de los Caballeros', 'country': 'Dominican Republic', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9af5'), 'date': datetime.datetime(2023, 10, 16, 0, 0), 'home_team': 'Saint Martin', 'away_team': 'Anguilla', 'home_score': 8, 'away_score': 0, 'tournament': 'CONCACAF Nations League', 'city': 'Basseterre', 'country': 'Saint Kitts and Nevis', 'neutral': True}
# {'_id': ObjectId('6692ad8188365a953ada9b06'), 'date': datetime.datetime(2023, 10, 17, 0, 0), 'home_team': 'Curaçao', 'away_team': 'Trinidad and Tobago', 'home_score': 5, 'away_score': 3, 'tournament': 'CONCACAF Nations League', 'city': 'Willemstad', 'country': 'Curaçao', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9b25'), 'date': datetime.datetime(2023, 10, 17, 0, 0), 'home_team': 'South Korea', 'away_team': 'Vietnam', 'home_score': 6, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Suwon', 'country': 'South Korea', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9b4c'), 'date': datetime.datetime(2023, 11, 16, 0, 0), 'home_team': 'Qatar', 'away_team': 'Afghanistan', 'home_score': 8, 'away_score': 1, 'tournament': 'FIFA World Cup qualification', 'city': 'Al Rayyan', 'country': 'Qatar', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9b4e'), 'date': datetime.datetime(2023, 11, 16, 0, 0), 'home_team': 'Japan', 'away_team': 'Myanmar', 'home_score': 5, 'away_score': 0, 'tournament': 'FIFA World Cup qualification', 'city': 'Suita', 'country': 'Japan', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9b51'), 'date': datetime.datetime(2023, 11, 16, 0, 0), 'home_team': 'South Korea', 'away_team': 'Singapore', 'home_score': 5, 'away_score': 0, 'tournament': 'FIFA World Cup qualification', 'city': 'Seoul', 'country': 'South Korea', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9b56'), 'date': datetime.datetime(2023, 11, 16, 0, 0), 'home_team': 'Iraq', 'away_team': 'Indonesia', 'home_score': 5, 'away_score': 1, 'tournament': 'FIFA World Cup qualification', 'city': 'Basra', 'country': 'Iraq', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9b5d'), 'date': datetime.datetime(2023, 11, 16, 0, 0), 'home_team': 'Australia', 'away_team': 'Bangladesh', 'home_score': 7, 'away_score': 0, 'tournament': 'FIFA World Cup qualification', 'city': 'Melbourne', 'country': 'Australia', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9b5e'), 'date': datetime.datetime(2023, 11, 16, 0, 0), 'home_team': 'Egypt', 'away_team': 'Djibouti', 'home_score': 6, 'away_score': 0, 'tournament': 'FIFA World Cup qualification', 'city': 'Cairo', 'country': 'Egypt', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9b7a'), 'date': datetime.datetime(2023, 11, 17, 0, 0), 'home_team': 'Ivory Coast', 'away_team': 'Seychelles', 'home_score': 9, 'away_score': 0, 'tournament': 'FIFA World Cup qualification', 'city': 'Abidjan', 'country': 'Ivory Coast', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9b83'), 'date': datetime.datetime(2023, 11, 17, 0, 0), 'home_team': 'Italy', 'away_team': 'North Macedonia', 'home_score': 5, 'away_score': 2, 'tournament': 'UEFA Euro qualification', 'city': 'Rome', 'country': 'Italy', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9b92'), 'date': datetime.datetime(2023, 11, 18, 0, 0), 'home_team': 'France', 'away_team': 'Gibraltar', 'home_score': 14, 'away_score': 0, 'tournament': 'UEFA Euro qualification', 'city': 'Nice', 'country': 'France', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9b99'), 'date': datetime.datetime(2023, 11, 18, 0, 0), 'home_team': 'New Caledonia', 'away_team': 'Tonga', 'home_score': 7, 'away_score': 0, 'tournament': 'Pacific Games', 'city': 'Honiara', 'country': 'Solomon Islands', 'neutral': True}
# {'_id': ObjectId('6692ad8188365a953ada9b9a'), 'date': datetime.datetime(2023, 11, 18, 0, 0), 'home_team': 'Fiji', 'away_team': 'Northern Mariana Islands', 'home_score': 10, 'away_score': 0, 'tournament': 'Pacific Games', 'city': 'Honiara', 'country': 'Solomon Islands', 'neutral': True}
# {'_id': ObjectId('6692ad8188365a953ada9b9b'), 'date': datetime.datetime(2023, 11, 19, 0, 0), 'home_team': 'Guadeloupe', 'away_team': 'Saint Kitts and Nevis', 'home_score': 5, 'away_score': 0, 'tournament': 'CONCACAF Nations League', 'city': 'Sainte-Anne', 'country': 'Guadeloupe', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9ba5'), 'date': datetime.datetime(2023, 11, 19, 0, 0), 'home_team': 'Belgium', 'away_team': 'Azerbaijan', 'home_score': 5, 'away_score': 0, 'tournament': 'UEFA Euro qualification', 'city': 'Brussels', 'country': 'Belgium', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9bad'), 'date': datetime.datetime(2023, 11, 20, 0, 0), 'home_team': 'Aruba', 'away_team': 'Cayman Islands', 'home_score': 5, 'away_score': 1, 'tournament': 'CONCACAF Nations League', 'city': 'Oranjestad', 'country': 'Aruba', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9bb8'), 'date': datetime.datetime(2023, 11, 20, 0, 0), 'home_team': 'Russia', 'away_team': 'Cuba', 'home_score': 8, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Volgograd', 'country': 'Russia', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9bc1'), 'date': datetime.datetime(2023, 11, 20, 0, 0), 'home_team': 'Samoa', 'away_team': 'American Samoa', 'home_score': 10, 'away_score': 0, 'tournament': 'Pacific Games', 'city': 'Honiara', 'country': 'Solomon Islands', 'neutral': True}
# {'_id': ObjectId('6692ad8188365a953ada9bc5'), 'date': datetime.datetime(2023, 11, 21, 0, 0), 'home_team': 'Guyana', 'away_team': 'Antigua and Barbuda', 'home_score': 6, 'away_score': 0, 'tournament': 'CONCACAF Nations League', 'city': 'Santo Domingo', 'country': 'Dominican Republic', 'neutral': True}
# {'_id': ObjectId('6692ad8188365a953ada9bc6'), 'date': datetime.datetime(2023, 11, 21, 0, 0), 'home_team': 'Puerto Rico', 'away_team': 'Bahamas', 'home_score': 6, 'away_score': 1, 'tournament': 'CONCACAF Nations League', 'city': 'Bayamón', 'country': 'Puerto Rico', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9bfd'), 'date': datetime.datetime(2023, 11, 23, 0, 0), 'home_team': 'Solomon Islands', 'away_team': 'American Samoa', 'home_score': 11, 'away_score': 0, 'tournament': 'Pacific Games', 'city': 'Honiara', 'country': 'Solomon Islands', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9c0d'), 'date': datetime.datetime(2024, 1, 1, 0, 0), 'home_team': 'Japan', 'away_team': 'Thailand', 'home_score': 5, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Tokyo', 'country': 'Japan', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9c1c'), 'date': datetime.datetime(2024, 1, 6, 0, 0), 'home_team': 'Ivory Coast', 'away_team': 'Sierra Leone', 'home_score': 5, 'away_score': 1, 'tournament': 'Friendly', 'city': 'San-Pédro', 'country': 'Ivory Coast', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9c1e'), 'date': datetime.datetime(2024, 1, 6, 0, 0), 'home_team': 'Mali', 'away_team': 'Guinea-Bissau', 'home_score': 6, 'away_score': 2, 'tournament': 'Friendly', 'city': 'Bamako', 'country': 'Mali', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9c26'), 'date': datetime.datetime(2024, 1, 9, 0, 0), 'home_team': 'Japan', 'away_team': 'Jordan', 'home_score': 6, 'away_score': 1, 'tournament': 'Friendly', 'city': 'Doha', 'country': 'Qatar', 'neutral': True}
# {'_id': ObjectId('6692ad8188365a953ada9cac'), 'date': datetime.datetime(2024, 3, 21, 0, 0), 'home_team': 'Guinea', 'away_team': 'Vanuatu', 'home_score': 6, 'away_score': 0, 'tournament': 'FIFA Series', 'city': 'Jeddah', 'country': 'Saudi Arabia', 'neutral': True}
# {'_id': ObjectId('6692ad8188365a953ada9cb0'), 'date': datetime.datetime(2024, 3, 21, 0, 0), 'home_team': 'Poland', 'away_team': 'Estonia', 'home_score': 5, 'away_score': 1, 'tournament': 'UEFA Euro qualification', 'city': 'Warsaw', 'country': 'Poland', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9cb5'), 'date': datetime.datetime(2024, 3, 21, 0, 0), 'home_team': 'Greece', 'away_team': 'Kazakhstan', 'home_score': 5, 'away_score': 0, 'tournament': 'UEFA Euro qualification', 'city': 'Athens', 'country': 'Greece', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9cbe'), 'date': datetime.datetime(2024, 3, 21, 0, 0), 'home_team': 'Iran', 'away_team': 'Turkmenistan', 'home_score': 5, 'away_score': 0, 'tournament': 'FIFA World Cup qualification', 'city': 'Tehran', 'country': 'Iran', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9cc4'), 'date': datetime.datetime(2024, 3, 21, 0, 0), 'home_team': 'Bahrain', 'away_team': 'Nepal', 'home_score': 5, 'away_score': 0, 'tournament': 'FIFA World Cup qualification', 'city': 'Riffa', 'country': 'Bahrain', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9cc7'), 'date': datetime.datetime(2024, 3, 21, 0, 0), 'home_team': 'Palestine', 'away_team': 'Bangladesh', 'home_score': 5, 'away_score': 0, 'tournament': 'FIFA World Cup qualification', 'city': 'Kuwait City', 'country': 'Kuwait', 'neutral': True}
# {'_id': ObjectId('6692ad8188365a953ada9cce'), 'date': datetime.datetime(2024, 3, 21, 0, 0), 'home_team': 'Portugal', 'away_team': 'Sweden', 'home_score': 5, 'away_score': 2, 'tournament': 'Friendly', 'city': 'Guimarães', 'country': 'Portugal', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9cd7'), 'date': datetime.datetime(2024, 3, 22, 0, 0), 'home_team': 'Central African Republic', 'away_team': 'Bhutan', 'home_score': 6, 'away_score': 0, 'tournament': 'FIFA Series', 'city': 'Colombo', 'country': 'Sri Lanka', 'neutral': True}
# {'_id': ObjectId('6692ad8188365a953ada9d19'), 'date': datetime.datetime(2024, 3, 26, 0, 0), 'home_team': 'Syria', 'away_team': 'Myanmar', 'home_score': 7, 'away_score': 0, 'tournament': 'FIFA World Cup qualification', 'city': 'Dammam', 'country': 'Saudi Arabia', 'neutral': True}
# {'_id': ObjectId('6692ad8188365a953ada9d1c'), 'date': datetime.datetime(2024, 3, 26, 0, 0), 'home_team': 'Kyrgyzstan', 'away_team': 'Taiwan', 'home_score': 5, 'away_score': 1, 'tournament': 'FIFA World Cup qualification', 'city': 'Bishkek', 'country': 'Kyrgyzstan', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9d23'), 'date': datetime.datetime(2024, 3, 26, 0, 0), 'home_team': 'Jordan', 'away_team': 'Pakistan', 'home_score': 7, 'away_score': 0, 'tournament': 'FIFA World Cup qualification', 'city': 'Amman', 'country': 'Jordan', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9d27'), 'date': datetime.datetime(2024, 3, 26, 0, 0), 'home_team': 'Australia', 'away_team': 'Lebanon', 'home_score': 5, 'away_score': 0, 'tournament': 'FIFA World Cup qualification', 'city': 'Canberra', 'country': 'Australia', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9d2b'), 'date': datetime.datetime(2024, 3, 26, 0, 0), 'home_team': 'Austria', 'away_team': 'Turkey', 'home_score': 6, 'away_score': 1, 'tournament': 'Friendly', 'city': 'Vienna', 'country': 'Austria', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9d61'), 'date': datetime.datetime(2024, 6, 5, 0, 0), 'home_team': 'Spain', 'away_team': 'Andorra', 'home_score': 5, 'away_score': 0, 'tournament': 'Friendly', 'city': 'Badajoz', 'country': 'Spain', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9d6b'), 'date': datetime.datetime(2024, 6, 5, 0, 0), 'home_team': 'Guatemala', 'away_team': 'Dominica', 'home_score': 6, 'away_score': 0, 'tournament': 'FIFA World Cup qualification', 'city': 'Guatemala City', 'country': 'Guatemala', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9d94'), 'date': datetime.datetime(2024, 6, 7, 0, 0), 'home_team': 'Czech Republic', 'away_team': 'Malta', 'home_score': 7, 'away_score': 1, 'tournament': 'Friendly', 'city': 'Grödig', 'country': 'Austria', 'neutral': True}
# {'_id': ObjectId('6692ad8188365a953ada9dae'), 'date': datetime.datetime(2024, 6, 8, 0, 0), 'home_team': 'Spain', 'away_team': 'Northern Ireland', 'home_score': 5, 'away_score': 1, 'tournament': 'Friendly', 'city': 'Mallorca', 'country': 'Spain', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9db3'), 'date': datetime.datetime(2024, 6, 8, 0, 0), 'home_team': 'Gambia', 'away_team': 'Seychelles', 'home_score': 5, 'away_score': 1, 'tournament': 'FIFA World Cup qualification', 'city': 'Berkane', 'country': 'Morocco', 'neutral': True}
# {'_id': ObjectId('6692ad8188365a953ada9de8'), 'date': datetime.datetime(2024, 6, 11, 0, 0), 'home_team': 'Morocco', 'away_team': 'Congo', 'home_score': 6, 'away_score': 0, 'tournament': 'FIFA World Cup qualification', 'city': 'Agadir', 'country': 'Morocco', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9df0'), 'date': datetime.datetime(2024, 6, 11, 0, 0), 'home_team': 'Japan', 'away_team': 'Syria', 'home_score': 5, 'away_score': 0, 'tournament': 'FIFA World Cup qualification', 'city': 'Hiroshima', 'country': 'Japan', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9dff'), 'date': datetime.datetime(2024, 6, 11, 0, 0), 'home_team': 'Australia', 'away_team': 'Palestine', 'home_score': 5, 'away_score': 0, 'tournament': 'FIFA World Cup qualification', 'city': 'Perth', 'country': 'Australia', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9e05'), 'date': datetime.datetime(2024, 6, 11, 0, 0), 'home_team': 'Puerto Rico', 'away_team': 'Anguilla', 'home_score': 8, 'away_score': 0, 'tournament': 'FIFA World Cup qualification', 'city': 'Bayamón', 'country': 'Puerto Rico', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9e08'), 'date': datetime.datetime(2024, 6, 14, 0, 0), 'home_team': 'Germany', 'away_team': 'Scotland', 'home_score': 5, 'away_score': 1, 'tournament': 'UEFA Euro', 'city': 'Munich', 'country': 'Germany', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9e16'), 'date': datetime.datetime(2024, 6, 16, 0, 0), 'home_team': 'Fiji', 'away_team': 'Papua New Guinea', 'home_score': 5, 'away_score': 1, 'tournament': 'Oceania Nations Cup', 'city': 'Suva', 'country': 'Fiji', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9e21'), 'date': datetime.datetime(2024, 6, 19, 0, 0), 'home_team': 'Fiji', 'away_team': 'Samoa', 'home_score': 9, 'away_score': 1, 'tournament': 'Oceania Nations Cup', 'city': 'Suva', 'country': 'Fiji', 'neutral': False}
# {'_id': ObjectId('6692ad8188365a953ada9e47'), 'date': datetime.datetime(2024, 6, 27, 0, 0), 'home_team': 'New Zealand', 'away_team': 'Tahiti', 'home_score': 5, 'away_score': 0, 'tournament': 'Oceania Nations Cup', 'city': 'Port Vila', 'country': 'Vanuatu', 'neutral': True}
# {'_id': ObjectId('6692ad8188365a953ada9e65'), 'date': datetime.datetime(2024, 7, 6, 0, 0), 'home_team': 'Colombia', 'away_team': 'Panama', 'home_score': 5, 'away_score': 0, 'tournament': 'Copa América', 'city': 'Glendale', 'country': 'United States', 'neutral': True}
